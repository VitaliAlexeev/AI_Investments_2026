# %% [markdown]
# # Risk Parity Portfolio Optimization
#
# ## 1. Downloading the data:

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import warnings

import riskfolio as rp
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")
pd.options.display.float_format = '{:.4%}'.format

# --- matplotlib 3.11 compatibility shim for Riskfolio-Lib 7.3 -------------
# matplotlib removed cm.get_cmap in 3.11 (deprecated since 3.7). Riskfolio's
# plot_frontier_area, plot_pie and plot_series still call it. Restore it.
import matplotlib
import matplotlib.cm as cm

if not hasattr(cm, "get_cmap"):
    def _get_cmap(name=None, lut=None):
        if name is None:
            name = matplotlib.rcParams["image.cmap"]
        if isinstance(name, matplotlib.colors.Colormap):
            return name
        cmap = matplotlib.colormaps[name]
        return cmap.resampled(lut) if lut is not None else cmap
    cm.get_cmap = _get_cmap

from matplotlib.axes import Axes
if not hasattr(Axes, "plot_date"):
    Axes.plot_date = lambda self, x, y, *a, **kw: self.plot(x, y, *a, **kw)
    

plt.rcParams["figure.figsize"] = (11, 6)
plt.rcParams["axes.grid"] = True
plt.rcParams["grid.alpha"] = 0.3
pd.set_option("display.width", 120)

def show():
    """plt.show(), tolerant of Riskfolio's colorbars.

    rp.plot_frontier attaches a colorbar, and current matplotlib raises
    RuntimeError if tight_layout() is called on a figure that already has one.
    Catch it rather than let a cosmetic call break the cell.
    """
    try:
        plt.tight_layout()
    except RuntimeError:
        pass
    plt.show()

# %%
# Date range
start = '2021-01-01'
end = '2024-10-30'

# Tickers of assets
assets = ['JCI', 'TGT', 'CMCSA', 'CPB', 'MO', 'APA', 'JPM',
          'ZION', 'PSA', 'BAX', 'BMY', 'LUV', 'PCAR', 'TXT', 'TMO',
          'DE', 'MSFT', 'HPQ', 'VZ', 'CNP', 'NI', 'T', 'BA']
assets.sort()

# Downloading data
data = yf.download(assets, start = start, end = end, auto_adjust=True)
data = data.loc[:,('Close', slice(None))]
data.columns = assets
# Out:
# [*********************100%***********************]  23 of 23 completed

# %%
# Calculating returns
Y = data[assets].pct_change().dropna()
Y.tail(5)
# Out:
#                 APA       BA      BAX      BMY   CMCSA      CNP      CPB       DE      HPQ      JCI  ...     MSFT  \
# Date                                                                                                 ...
# 2024-10-23 -2.7403% -1.7638% -0.3280%  0.5686% 0.0000% -0.1343% -0.8446%  0.4894% -1.0488% -0.2088%  ... -0.6807%
# 2024-10-24  0.7350% -1.1843%  0.7129% -0.2639% 0.2407% -0.9076%  0.0639%  0.5946%  1.7294%  0.4969%  ...  0.0306%
# 2024-10-25  0.6080% -0.1224% -2.0691% -1.8897% 0.0240% -0.5767%  0.1702% -0.7639%  1.1242% -0.1561%  ...  0.8052%
# 2024-10-28 -4.5125% -2.7869%  0.1112%  1.3868% 0.4321%  1.5012%  1.1897%  1.0835%  1.4642%  1.2901%  ... -0.3644%
# 2024-10-29 -1.6456%  1.5197% -0.0555% -0.2660% 0.5497% -1.0756% -1.8266% -1.5303% -0.9621% -0.8491%  ...  1.2565%
#
#                  NI     PCAR      PSA        T      TGT      TMO      TXT       VZ     ZION
# Date
# 2024-10-23  1.5531% -0.9447%  1.4481%  4.6046% -0.7641% -1.6866% -0.7767%  3.2771% -1.1807%
# 2024-10-24 -0.1416%  1.0019% -0.4003% -1.2894%  1.4387% -3.3149% -6.1932% -2.3332%  0.5589%
# 2024-10-25 -1.2479%  1.0111% -0.6117% -1.6667%  0.6525% -0.5382%  1.0553% -1.1467% -1.6098%
# 2024-10-28  0.9190%  1.1048%  0.0803%  1.2826% -1.2305% -0.3319%  1.1172%  0.5800%  2.2789%
# 2024-10-29 -2.0489% -0.3736% -1.5894%  0.3166% -0.9176% -0.8633% -1.8014% -0.6968% -0.7237%
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 2. Estimating Mean Variance Portfolios
#
# ### 2.1 Calculating the portfolio that maximizes Sharpe ratio.

# %%
# Building the portfolio object
port = rp.Portfolio(returns=Y)

# Calculating optimal portfolio

# Select method and estimate input parameters:
method_mu='hist' # Method to estimate expected returns based on historical data.
method_cov='hist' # Method to estimate covariance matrix based on historical data.
port.assets_stats(method_mu=method_mu, method_cov=method_cov)

# Estimate optimal portfolio:
model='Classic' # Could be Classic (historical), BL (Black Litterman) or FM (Factor Model)
rm = 'MV' # Risk measure used, this time will be variance
obj = 'Sharpe' # Objective function, could be MinRisk, MaxRet, Utility or Sharpe
hist = True # Use historical scenarios for risk measures that depend on scenarios
rf = 0 # Risk free rate
l = 0 # Risk aversion factor, only useful when obj is 'Utility'

w = port.optimization(model=model, rm=rm, obj=obj, rf=rf, l=l, hist=hist)
w.T
# Out:
#             APA      BA     BAX     BMY   CMCSA     CNP     CPB      DE     HPQ     JCI  ...     MSFT       NI  \
# weights 1.7367% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000%  ... 20.1587% 18.5790%
#
#             PCAR     PSA       T     TGT     TMO     TXT      VZ    ZION
# weights 19.4083% 9.7480% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000%
#
# [1 rows x 23 columns]

# %% [markdown]
# ### 2.2 Plotting portfolio composition

# %%
# Plotting the composition of the portfolio
ax = rp.plot_pie(w=w, title='Sharpe Mean Variance', others=0.05, nrow=25, height=6, width=10, ax=None)

# %% [markdown]
# ### 2.3 Plotting Risk Composition

# %%
# Plotting the risk composition of the portfolio
ax = rp.plot_risk_con(w, cov=port.cov, returns=port.returns, rm=rm, rf=0, alpha=0.01,
                      color="tab:blue", height=6, width=10, ax=None)

# %% [markdown]
# ## 3. Estimating Risk Parity Portfolios for Other Risk Measures
#
# In this part I will calculate risk parity portfolios. First I'm going to calculate risk parity portfolio when we use variance as risk measure, then I'm going to calculate the risk parity portfolios for all available risk measures.
#
# ### 3.1 Calculating the risk parity portfolio for variance.

# %%
b = None # Risk contribution constraints vector

w_rp = port.rp_optimization(model=model, rm=rm, rf=rf, b=b, hist=hist)
w.T
# Out:
#             APA      BA     BAX     BMY   CMCSA     CNP     CPB      DE     HPQ     JCI  ...     MSFT       NI  \
# weights 1.7367% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000%  ... 20.1587% 18.5790%
#
#             PCAR     PSA       T     TGT     TMO     TXT      VZ    ZION
# weights 19.4083% 9.7480% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000% 0.0000%
#
# [1 rows x 23 columns]

# %% [markdown]
# ### 3.2 Plotting portfolio composition

# %%
ax = rp.plot_pie(w=w_rp, title='Risk Parity Variance', others=0.05, nrow=25, cmap = "tab20",
                 height=6, width=10, ax=None)

# %% [markdown]
# ### 3.3  Plotting Risk Composition

# %%
ax = rp.plot_risk_con(w_rp, cov=port.cov, returns=port.returns, rm=rm, rf=0, alpha=0.01,
                      color="tab:blue", height=6, width=10, ax=None)

# %% [markdown]
# ### 3.4 Calculate Optimal Portfolios for Several Risk Measures

# %%
# Risk Measures available:
#
# 'MV': Standard Deviation.
# 'MAD': Mean Absolute Deviation.
# 'MSV': Semi Standard Deviation.
# 'FLPM': First Lower Partial Moment (Omega Ratio).
# 'SLPM': Second Lower Partial Moment (Sortino Ratio).
# 'CVaR': Conditional Value at Risk.
# 'EVaR': Entropic Value at Risk.
# 'CDaR': Conditional Drawdown at Risk of uncompounded cumulative returns.
# 'EDaR': Entropic Drawdown at Risk of uncompounded cumulative returns.
# 'UCI': Ulcer Index of uncompounded cumulative returns.

rms = ['MV', 'MAD', 'MSV', 'FLPM', 'SLPM', 'CVaR',
       'EVaR', 'CDaR', 'UCI', 'EDaR']

w_s = pd.DataFrame([])
port.solvers = ['MOSEK']
#port.sol_params = {'MOSEK': {'tol': 1e-8}}  # Adjust tolerance if needed

for i in rms:
    port = rp.Portfolio(returns=Y)
    method_mu='hist' # Method to estimate expected returns based on historical data.
    method_cov='hist' # Method to estimate covariance matrix based on historical data.
    port.assets_stats(method_mu=method_mu, method_cov=method_cov)

    w = port.rp_optimization(model=model, rm=i, rf=rf, b=b, hist=hist)
    w_s = pd.concat([w_s, w], axis=1)
    print(i)
    
w_s.columns = rms
# Out:
# MV
# MAD
# MSV
# FLPM
# SLPM
# CVaR
# EVaR
# CDaR
# UCI
# EDaR

# %%
w_s.style.format("{:.2%}").background_gradient(cmap='YlGn')
# Out:
# <style type="text/css">
# #T_56bc2_row0_col0, #T_56bc2_row0_col5, #T_56bc2_row1_col6, #T_56bc2_row4_col8 {
#   background-color: #fbfdce;
#   color: #000000;
# }
# #T_56bc2_row0_col1, #T_56bc2_row0_col2, #T_56bc2_row22_col7 {
#   background-color: #fcfed3;
#   color: #000000;
# }
# #T_56bc2_row0_col3 {
#   background-color: #fafdcc;
#   color: #000000;
# }
# #T_56bc2_row0_col4, #T_56bc2_row7_col8, #T_56bc2_row12_col9, #T_56bc2_row16_col8, #T_56bc2_row22_col8, #T_56bc2_row22_col9 {
#   background-color: #fbfed2;
#   color: #000000;
# }
# #T_56bc2_row0_col6, #T_56bc2_row1_col2, #T_56bc2_row11_col5, #T_56bc2_row12_col8 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_56bc2_row0_col7 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_56bc2_row0_col8, #T_56bc2_row10_col5 {
#   background-color: #d5eea1;
#   color: #000000;
# }
# #T_56bc2_row0_col9, #T_56bc2_row8_col0, #T_56bc2_row18_col0, #T_56bc2_row20_col9 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_56bc2_row1_col0, #T_56bc2_row11_col0, #T_56bc2_row13_col7, #T_56bc2_row20_col2 {
#   background-color: #f0f9b4;
#   color: #000000;
# }
# #T_56bc2_row1_col1, #T_56bc2_row20_col1 {
#   background-color: #e4f4ab;
#   color: #000000;
# }
# #T_56bc2_row1_col3, #T_56bc2_row20_col4 {
#   background-color: #eff9b3;
#   color: #000000;
# }
# #T_56bc2_row1_col4, #T_56bc2_row11_col4, #T_56bc2_row13_col9 {
#   background-color: #f7fcba;
#   color: #000000;
# }
# #T_56bc2_row1_col5, #T_56bc2_row14_col7 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_56bc2_row1_col7, #T_56bc2_row7_col7 {
#   background-color: #fdfed9;
#   color: #000000;
# }
# #T_56bc2_row1_col8, #T_56bc2_row12_col7 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_56bc2_row1_col9, #T_56bc2_row9_col7, #T_56bc2_row16_col7, #T_56bc2_row16_col9 {
#   background-color: #fdfedd;
#   color: #000000;
# }
# #T_56bc2_row2_col0, #T_56bc2_row5_col0, #T_56bc2_row13_col2, #T_56bc2_row17_col5 {
#   background-color: #95d385;
#   color: #000000;
# }
# #T_56bc2_row2_col1, #T_56bc2_row10_col6 {
#   background-color: #7ac77a;
#   color: #000000;
# }
# #T_56bc2_row2_col2 {
#   background-color: #93d284;
#   color: #000000;
# }
# #T_56bc2_row2_col3, #T_56bc2_row20_col8 {
#   background-color: #b2df90;
#   color: #000000;
# }
# #T_56bc2_row2_col4, #T_56bc2_row7_col6, #T_56bc2_row9_col6 {
#   background-color: #acdd8e;
#   color: #000000;
# }
# #T_56bc2_row2_col5, #T_56bc2_row4_col3 {
#   background-color: #c8e99b;
#   color: #000000;
# }
# #T_56bc2_row2_col6 {
#   background-color: #66bd70;
#   color: #f1f1f1;
# }
# #T_56bc2_row2_col7, #T_56bc2_row4_col9 {
#   background-color: #feffde;
#   color: #000000;
# }
# #T_56bc2_row2_col8 {
#   background-color: #feffdf;
#   color: #000000;
# }
# #T_56bc2_row2_col9, #T_56bc2_row8_col9 {
#   background-color: #feffe1;
#   color: #000000;
# }
# #T_56bc2_row3_col0 {
#   background-color: #218242;
#   color: #f1f1f1;
# }
# #T_56bc2_row3_col1 {
#   background-color: #0e743c;
#   color: #f1f1f1;
# }
# #T_56bc2_row3_col2 {
#   background-color: #248644;
#   color: #f1f1f1;
# }
# #T_56bc2_row3_col3 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_56bc2_row3_col4 {
#   background-color: #298c48;
#   color: #f1f1f1;
# }
# #T_56bc2_row3_col5 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_56bc2_row3_col6, #T_56bc2_row6_col0, #T_56bc2_row6_col1, #T_56bc2_row6_col2, #T_56bc2_row6_col3, #T_56bc2_row6_col4, #T_56bc2_row6_col5, #T_56bc2_row6_col7, #T_56bc2_row6_col8, #T_56bc2_row6_col9 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_56bc2_row3_col7, #T_56bc2_row8_col3, #T_56bc2_row8_col4 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_56bc2_row3_col8 {
#   background-color: #e3f4aa;
#   color: #000000;
# }
# #T_56bc2_row3_col9, #T_56bc2_row8_col2 {
#   background-color: #eaf7af;
#   color: #000000;
# }
# #T_56bc2_row4_col0, #T_56bc2_row15_col4, #T_56bc2_row17_col7 {
#   background-color: #bce395;
#   color: #000000;
# }
# #T_56bc2_row4_col1, #T_56bc2_row19_col5 {
#   background-color: #b6e192;
#   color: #000000;
# }
# #T_56bc2_row4_col2, #T_56bc2_row15_col0 {
#   background-color: #bde496;
#   color: #000000;
# }
# #T_56bc2_row4_col4, #T_56bc2_row15_col2 {
#   background-color: #c4e799;
#   color: #000000;
# }
# #T_56bc2_row4_col5 {
#   background-color: #c7e89a;
#   color: #000000;
# }
# #T_56bc2_row4_col6, #T_56bc2_row10_col3 {
#   background-color: #b8e293;
#   color: #000000;
# }
# #T_56bc2_row4_col7 {
#   background-color: #fcfed6;
#   color: #000000;
# }
# #T_56bc2_row5_col1 {
#   background-color: #69bf72;
#   color: #000000;
# }
# #T_56bc2_row5_col2, #T_56bc2_row19_col2 {
#   background-color: #a1d889;
#   color: #000000;
# }
# #T_56bc2_row5_col3, #T_56bc2_row16_col1 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_56bc2_row5_col4 {
#   background-color: #9dd688;
#   color: #000000;
# }
# #T_56bc2_row5_col5, #T_56bc2_row10_col1 {
#   background-color: #c1e698;
#   color: #000000;
# }
# #T_56bc2_row5_col6 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_56bc2_row5_col7 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_56bc2_row5_col8, #T_56bc2_row17_col8 {
#   background-color: #d3eda0;
#   color: #000000;
# }
# #T_56bc2_row5_col9 {
#   background-color: #f6fcb8;
#   color: #000000;
# }
# #T_56bc2_row6_col6 {
#   background-color: #349a52;
#   color: #f1f1f1;
# }
# #T_56bc2_row7_col0, #T_56bc2_row7_col4 {
#   background-color: #ddf1a6;
#   color: #000000;
# }
# #T_56bc2_row7_col1 {
#   background-color: #d7efa2;
#   color: #000000;
# }
# #T_56bc2_row7_col2, #T_56bc2_row9_col2 {
#   background-color: #ddf2a6;
#   color: #000000;
# }
# #T_56bc2_row7_col3 {
#   background-color: #dbf1a4;
#   color: #000000;
# }
# #T_56bc2_row7_col5, #T_56bc2_row10_col4 {
#   background-color: #c5e89a;
#   color: #000000;
# }
# #T_56bc2_row7_col9, #T_56bc2_row8_col8 {
#   background-color: #fcfed7;
#   color: #000000;
# }
# #T_56bc2_row8_col1 {
#   background-color: #e7f6ad;
#   color: #000000;
# }
# #T_56bc2_row8_col5, #T_56bc2_row18_col1, #T_56bc2_row20_col7 {
#   background-color: #def2a7;
#   color: #000000;
# }
# #T_56bc2_row8_col6, #T_56bc2_row20_col6 {
#   background-color: #e2f4aa;
#   color: #000000;
# }
# #T_56bc2_row8_col7, #T_56bc2_row9_col9 {
#   background-color: #fdfedb;
#   color: #000000;
# }
# #T_56bc2_row9_col0, #T_56bc2_row9_col4, #T_56bc2_row9_col5 {
#   background-color: #dcf1a5;
#   color: #000000;
# }
# #T_56bc2_row9_col1, #T_56bc2_row10_col0, #T_56bc2_row10_col2 {
#   background-color: #ccea9d;
#   color: #000000;
# }
# #T_56bc2_row9_col3, #T_56bc2_row13_col6 {
#   background-color: #ceeb9e;
#   color: #000000;
# }
# #T_56bc2_row9_col8 {
#   background-color: #fbfed0;
#   color: #000000;
# }
# #T_56bc2_row10_col7, #T_56bc2_row18_col5, #T_56bc2_row19_col7, #T_56bc2_row21_col8 {
#   background-color: #f9fdc4;
#   color: #000000;
# }
# #T_56bc2_row10_col8, #T_56bc2_row20_col0 {
#   background-color: #edf8b1;
#   color: #000000;
# }
# #T_56bc2_row10_col9 {
#   background-color: #fafdcb;
#   color: #000000;
# }
# #T_56bc2_row11_col1 {
#   background-color: #ebf7b0;
#   color: #000000;
# }
# #T_56bc2_row11_col2, #T_56bc2_row17_col9, #T_56bc2_row18_col2 {
#   background-color: #f3fab6;
#   color: #000000;
# }
# #T_56bc2_row11_col3 {
#   background-color: #f5fbb8;
#   color: #000000;
# }
# #T_56bc2_row11_col6 {
#   background-color: #e0f3a8;
#   color: #000000;
# }
# #T_56bc2_row11_col7, #T_56bc2_row11_col8 {
#   background-color: #feffe2;
#   color: #000000;
# }
# #T_56bc2_row11_col9 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_56bc2_row12_col0 {
#   background-color: #4ab062;
#   color: #f1f1f1;
# }
# #T_56bc2_row12_col1, #T_56bc2_row12_col3, #T_56bc2_row13_col1 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_56bc2_row12_col2, #T_56bc2_row15_col9 {
#   background-color: #55b567;
#   color: #f1f1f1;
# }
# #T_56bc2_row12_col4, #T_56bc2_row21_col5 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_56bc2_row12_col5 {
#   background-color: #47ae60;
#   color: #f1f1f1;
# }
# #T_56bc2_row12_col6 {
#   background-color: #5ab76a;
#   color: #f1f1f1;
# }
# #T_56bc2_row13_col0, #T_56bc2_row14_col2, #T_56bc2_row16_col4, #T_56bc2_row19_col3 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_56bc2_row13_col3 {
#   background-color: #339951;
#   color: #f1f1f1;
# }
# #T_56bc2_row13_col4, #T_56bc2_row17_col4 {
#   background-color: #88cd7f;
#   color: #000000;
# }
# #T_56bc2_row13_col5 {
#   background-color: #cbea9c;
#   color: #000000;
# }
# #T_56bc2_row13_col8, #T_56bc2_row16_col3 {
#   background-color: #5db96b;
#   color:

# %%
import matplotlib.pyplot as plt

# Plotting a comparison of assets weights for each portfolio

fig = plt.gcf()
fig.set_figwidth(16)
fig.set_figheight(6)
ax = fig.subplots(nrows=1, ncols=1)

w_s.plot.bar(ax=ax)
# Out:
# <Axes: >
